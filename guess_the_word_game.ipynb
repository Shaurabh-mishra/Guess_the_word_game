# %%
#!/usr/bin/env python
# coding: utf-8

# In[3]:


def a_word():
    fh=open('paragraph.txt')
    fh=fh.read()
    fh=fh.rstrip()
    fh=fh.lower()
    words=fh.split()
    import random
    word=random.choice(words)
    return word


# In[4]:


def Print(word):
    print('guess the word:')
    for el in word:
        print('*',end="")


# In[5]:


def chance(word,num):
    str=""
    count=0
    while count<num:
        char=input('\n enter a charecter: ')
        try:
            if char in word:
                if char in str:
                    print("\n false ")
                    count+=1
                    print(num-count, 'more attempt left...')
                    continue
                for el in word:
                    if el==char:
                        str=str+char
                        print(char,end="")
                    elif el in str:
                        print(el,end="")
                    else:
                        print('*',end="")
                        
                        
            else:
                count=count+1
                print("False")
                print(num-count, 'more attempt left...')
        except:
            print("Invalid input!")
        if len(str)==len(word):
            print('\nYOU WIN!')
            print("You found the word:",word)
            break
        elif num==count:
            print("YOU lOSE!")
            print("The word is:", word)
            print("Try next time..")
            
            


# In[6]:


def word_game():
    name=input('Enter your name: ')
    print('Welcome' ,name ,'!')
    word=a_word()
    Print(word)
    num=2*len(word)
    chance(word,num)
    print("If you want to continue press 1 other wise press 0:")
    while(True):
        try:
            x=int(input('Enter a no.'))   
            if x==1:
                word_game()
            else:
                break
        except:
            print("Please Enter a valid no.")
            continue
        
    
    
   
    


# In[7]:



word_game()
input()

# In[ ]:
# Out:
# Enter your name: a
# Welcome a !
# guess the word:
# ***
#  enter a charecter: a
# False
# 5 more attempt left...
#
#  enter a charecter: d
# False
# 4 more attempt left...
#
#  enter a charecter: s
# **s
#  enter a charecter: u
# False
# 3 more attempt left...
#
#  enter a charecter: b
# False
# 2 more attempt left...
#
#  enter a charecter: h
# h*s
#  enter a charecter: i
# his
# YOU WIN!
# You found the word: his
# If you want to continue press 1 other wise press 0:
# Enter a no.0
# ''
